# %%
! pip install langgraph==1.2.2 langchain==1.3.2 langchain-groq==1.1.3 langchain-ollama==1.1.0 langchain-google-genai==4.2.4 google-genai langchain-mistralai==1.1.6 langchain-community==0.4.2 langchain-tavily==0.2.18 psycopg[binary]==3.3.4 psycopg_pool==3.3.1 python-dotenv==1.2.2 tavily-python==0.7.24 requests==2.34.2 langgraph-checkpoint-postgres==3.1.0 python-dotenv
# Out:
# Collecting langgraph==1.2.2
#   Downloading langgraph-1.2.2-py3-none-any.whl.metadata (8.0 kB)
# Collecting langchain==1.3.2
#   Downloading langchain-1.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-groq==1.1.3
#   Downloading langchain_groq-1.1.3-py3-none-any.whl.metadata (2.9 kB)
# Collecting langchain-ollama==1.1.0
#   Downloading langchain_ollama-1.1.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-google-genai==4.2.4
#   Downloading langchain_google_genai-4.2.4-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: google-genai in /usr/local/lib/python3.13/dist-packages (2.12.1)
# Collecting langchain-mistralai==1.1.6
#   Downloading langchain_mistralai-1.1.6-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-community==0.4.2
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-tavily==0.2.18
#   Downloading langchain_tavily-0.2.18-py3-none-any.whl.metadata (20 kB)
# Collecting psycopg==3.3.4 (from psycopg[binary]==3.3.4)
#   Downloading psycopg-3.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting psycopg_pool==3.3.1
#   Downloading psycopg_pool-3.3.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting python-dotenv==1.2.2
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting tavily-python==0.7.24
#   Downloading tavily_python-0.7.24-py3-none-any.whl.metadata (11 kB)
# Collecting requests==2.34.2
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting langgraph-checkpoint-postgres==3.1.0
#   Downloading langgraph_checkpoint_postgres-3.1.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: langchain-core<2,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langgraph==1.2.2) (1.6.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph==1.2.2) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph==1.2.2) (1.1.0)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph==1.2.2)
#   Downloading langgraph_sdk-0.3.15-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pydantic>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langgraph==1.2.2) (2.13.5)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langgraph==1.2.2) (4.0.1)
# Collecting groq<1.0.0,>=0.30.0 (from langchain-groq==1.1.3)
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Collecting ollama<1.0.0,>=0.6.1 (from langchain-ollama==1.1.0)
#   Downloading ollama-0.6.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai==4.2.4)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpx-sse<1.0.0,>=0.3.1 (from langchain-mistralai==1.1.6)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.25.2 in /usr/local/lib/python3.13/dist-packages (from langchain-mistralai==1.1.6) (0.28.1)
# Requirement already satisfied: tokenizers<1.0.0,>=0.15.1 in /usr/local/lib/python3.13/dist-packages (from langchain-mistralai==1.1.6) (0.23.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.13/dist-packages (from langchain-community==0.4.2) (3.14.3)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community==0.4.2)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.13/dist-packages (from langchain-community==0.4.2) (0.12.1)
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community==0.4.2) (2.1.3)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community==0.4.2)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community==0.4.2) (6.0.3)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community==0.4.2) (2.0.52)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community==0.4.2) (9.1.4)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.13/dist-packages (from psycopg_pool==3.3.1) (4.16.0)
# Requirement already satisfied: tiktoken>=0.5.1 in /usr/local/lib/python3.13/dist-packages (from tavily-python==0.7.24) (0.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests==2.34.2) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests==2.34.2) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests==2.34.2) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.13/dist-packages (from requests==2.34.2) (2026.7.22)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.13/dist-packages (from langgraph-checkpoint-postgres==3.1.0) (3.12.0)
# Collecting psycopg-binary==3.3.4 (from psycopg[binary]==3.3.4)
#   Downloading psycopg_binary-3.3.4-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.14.2)
# Requirement already satisfied: google-auth<2.56.0,>=2.48.1 in /usr/local/lib/python3.13/dist-packages (from google-auth[requests]<2.56.0,>=2.48.1->google-genai) (2.49.0)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.2) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.2) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.2) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.2) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.2) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.2) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.2) (1.24.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai) (50.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.13/dist-packages (from google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai) (4.9.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.25.2->langchain-mistralai==1.1.6) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.25.2->langchain-mistralai==1.1.6) (0.16.0)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community==0.4.2)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2,>=1.4.0->langgraph==1.2.2) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2,>=1.4.0->langgraph==1.2.2) (0.0.19)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2,>=1.4.0->langgraph==1.2.2) (26.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2,>=1.4.0->langgraph==1.2.2) (0.17.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph==1.2.2) (1.12.2)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.2) (2.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.2) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.2) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.7.4->langgraph==1.2.2) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.7.4->langgraph==1.2.2) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.7.4->langgraph==1.2.2) (0.4.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community==0.4.2) (3.5.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.13/dist-packages (from tiktoken>=0.5.1->tavily-python==0.7.24) (2025.11.3)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.13/dist-packages (from tokenizers<1.0.0,>=0.15.1->langchain-mistralai==1.1.6) (1.29.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai) (2.1.1)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community==0.4.2) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain-community==0.4.2) (0.10.4)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0.0,>=0.15.1->langchain-mistralai==1.1.6) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0.0,>=0.15.1->langchain-mistralai==1.1.6) (3.32.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0.0,>=0.15.1->langchain-mistralai==1.1.6) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0.0,>=0.15.1->langchain-mistralai==1.1.6) (1.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0.0,>=0.15.1->langchain-mistralai==1.1.6) (4.67.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.0->langgraph==1.2.2) (3.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai) (3.0)
# Downloading langgraph-1.2.2-py3-none-any.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.4/236.4 kB 5.0 MB/s eta 0:00:00
# Downloading langchain-1.3.2-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 6.7 MB/s eta 0:00:00
# Downloading langchain_groq-1.1.3-py3-none-any.whl (20 kB)
# Downloading langchain_ollama-1.1.0-py3-none-any.whl (31 kB)
# Downloading langchain_google_genai-4.2.4-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 3.0 MB/s eta 0:00:00
# Downloading langchain_mistralai-1.1.6-py3-none-any.whl (22 kB)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 25.9 MB/s eta 0:00:00
# Downloading langchain_tavily-0.2.18-py3-none-any.whl (30 kB)
# Downloading psycopg-3.3.4-py3-none-any.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 kB 11.1 MB/s eta 0:00:00
# Downloading psycopg_pool-3.3.1-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 1.6 MB/s eta 0:00:00
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading tavily_python-0.7.24-py3-none-any.whl (20 kB)
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 3.5 MB/s eta 0:00:00
# Downloading langgraph_checkpoint_postgres-3.1.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 3.5 MB/s eta 0:00:00
# Downloading psycopg_binary-3.3.4-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 86.4 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 10.7 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.3 MB/s eta 0:00:00
# Downloading langgraph_sdk-0.3.15-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 7.7 MB/s eta 0:00:00
# Downloading ollama-0.6.2-py3-none-any.whl (15 kB)
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.4 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: filetype, requests, python-dotenv, psycopg_pool, psycopg-binary, psycopg, httpx-sse, tavily-python, pydantic-settings, ollama, langgraph-sdk, groq, langchain-text-splitters, langchain-ollama, langchain-mistralai, langchain-groq, langgraph-checkpoint-postgres, langchain-google-genai, langchain-classic, langgraph, langchain-community, langchain, langchain-tavily
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.2.3
#     Uninstalling python-dotenv-1.2.3:
#       Successfully uninstalled python-dotenv-1.2.3
#   Attempting uninstall: langgraph-sdk
#     Found existing installation: langgraph-sdk 0.4.4
#     Uninstalling langgraph-sdk-0.4.4:
#       Successfully uninstalled langgraph-sdk-0.4.4
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.2.11
#     Uninstalling langgraph-1.2.11:
#       Successfully uninstalled langgraph-1.2.11
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.18
#     Uninstalling langchain-1.3.18:
#       Successfully uninstalled langchain-1.3.18
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed filetype-1.2.0 groq-0.37.1 httpx-sse-0.4.3 langchain-1.3.2 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-google-genai-4.2.4 langchain-groq-1.1.3 langchain-mistralai-1.1.6 langchain-ollama-1.1.0 langchain-tavily-0.2.18 langchain-text-splitters-1.1.2 langgraph-1.2.2 langgraph-checkpoint-postgres-3.1.0 langgraph-sdk-0.3.15 ollama-0.6.2 psycopg-3.3.4 psycopg-binary-3.3.4 psycopg_pool-3.3.1 pydantic-settings-2.15.0 python-dotenv-1.2.2 requests-2.34.2 tavily-python-0.7.24

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from dotenv import load_dotenv
load_dotenv(dotenv_path='/content/.env')
# Out:
# True

# %%
import os
import operator
import re

from datetime import date, timedelta
from pathlib import Path

from pydantic import BaseModel, Field
from typing import TypedDict, List, Annotated, Optional, Literal
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_mistralai import ChatMistralAI
from langchain_groq import ChatGroq
from langchain_ollama import ChatOllama

from langchain_core.messages import HumanMessage, SystemMessage
from langchain_community.tools.tavily_search import TavilySearchResults

import psycopg
from psycopg.rows import dict_row
from langgraph.checkpoint.postgres import PostgresSaver

# %%
# Function to get DB URL

def get_database_url():
  '''
  Function to get database URL
  '''
  database_url = os.getenv('DATABASE_URL')
  if not database_url:
      raise ValueError(
            "DATABASE_URL is missing. Please add your Render PostgreSQL External Database URL to .env"
      )

  if "sslmode=" not in database_url:
      separator = "&" if "?" in database_url else "?"
      database_url = f"{database_url}{separator}sslmode=require"

  return database_url

# %%
# MISTRAL_API_KEY = os.getenv("MISTRAL_API_KEY")
# if not MISTRAL_API_KEY:
#     raise ValueError("MISTRAL_API_KEY is missing. Please add it to your .env file.")

# %%
# GROQ_API_KEY = os.getenv("GROQ_API_KEY")
# if not GROQ_API_KEY:
#     raise ValueError("GROQ_API_KEY is missing. Please add it to your .env file.")

# %%
class Task(BaseModel):
  id: int
  title: str

  goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
  bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
  target_words: int = Field(..., description="Target word count for this section (120–550).")

  tags: List[str] = Field(default_factory=list)
  requires_research: bool = False
  requires_citations: bool = False
  requires_code: bool = False

# %%
class Plan(BaseModel):
  blog_title: str
  audience: str
  tone: str
  blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"
  constraints: List[str] = Field(default_factory=list)
  tasks: List[Task]

# %%
class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # keep if Tavily provides; DO NOT rely on it
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    queries: List[str] = Field(default_factory=list)


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # workers/ reducer
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)
    final: str

# %%
# llm = ChatGroq(
#     model="llama-3.1-8b-instant",
#     temperature=0.7,
#     api_key=GROQ_API_KEY
# )

# %%
# llm2 = ChatMistralAI(
#     model="mistral-small-2506",
#     temperature=0.8,
#     api_key=MISTRAL_API_KEY
# )

# %%
llm = ChatOllama(
    model="llama3.1:8b",
    base_url="https://reentry-subject-mannish.ngrok-free.dev",
    temperature=0,
    num_ctx=32768,
)

# %%
llm.invoke("What is agentic ai")
# Out:
# AIMessage(content='Agentic AI refers to a type of artificial intelligence (AI) that is designed to exhibit autonomous, self-directed behavior, similar to that of humans or animals. Agentic AI systems are capable of making decisions, taking actions, and adapting to their environment in a way that is not predetermined by their programming.\n\nThe term "agentic" comes from the concept of agency, which refers to the ability of an entity to act independently and make decisions that affect its own goals and outcomes. In the context of AI, agentic refers to the ability of a system to act as an autonomous agent, with its own goals, motivations, and decision-making processes.\n\nAgentic AI systems are often designed to be more flexible and adaptable than traditional AI systems, which are typically programmed to perform specific tasks in a predetermined way. Agentic AI systems can learn from experience, adapt to new situations, and make decisions based on their own goals and motivations.\n\nSome key characteristics of agentic AI include:\n\n1. **Autonomy**: Agentic AI systems can operate independently, making decisions and taking actions without human intervention.\n2. **Self-directed behavior**: Agentic AI systems can set their own goals and priorities, and make decisions based on their own motivations.\n3. **Adaptability**: Agentic AI systems can adapt to new situations and learn from experience.\n4. **Goal-directed behavior**: Agentic AI systems can pursue their own goals and objectives, rather than simply following a predetermined set of instructions.\n5. **Self-awareness**: Agentic AI systems may have some level of self-awareness, allowing them to reflect on their own behavior and make decisions based on their own understanding of themselves.\n\nAgentic AI has many potential applications, including:\n\n1. **Autonomous vehicles**: Agentic AI systems can be used to control self-driving cars, which can navigate complex environments and make decisions in real-time.\n2. **Robotics**: Agentic AI systems can be used to control robots that can perform complex tasks, such as assembly or surgery.\n3. **Virtual assistants**: Agentic AI systems can be used to create virtual assistants that can learn from user behavior and adapt to their needs.\n4. **Healthcare**: Agentic AI systems can be used to develop personalized treatment plans for patients, taking into account their individual needs and goals.\n\nHowever, agentic AI also raises important questions and concerns, such as:\n\n1. **Accountability**: Who is responsible when an agentic AI system makes a decision that has negative consequences?\n2. **Transparency**: How can we understand the decision-making processes of an agentic AI system?\n3. **Safety**: How can we ensure that agentic AI systems do not pose a risk to humans or the environment?\n\nOverall, agentic AI has the potential to revolutionize many areas of life, but it also requires careful consideration of the potential risks and challenges associated with its development and deployment.', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-09-13T16:25:44.595989973Z', 'done': True, 'done_reason': 'stop', 'total_duration': 18018055458, 'load_duration': 1207035, 'prompt_eval_count': 15, 'prompt_eval_duration': 37343000, 'eval_count': 584, 'eval_duration': 17906262000, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--01a09b96-7eac-71b0-a6b1-9ddf74de2570-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 584, 'total_tokens': 599})

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------

ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- If user asked for "last week/this week/latest", reflect that constraint IN THE QUERIES.
"""

def router_node(state: State) -> dict:

    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}"),
        ]
    )

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
# -----------------------------
# 4) Research (Tavily)
# -----------------------------
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:

    tool = TavilySearchResults(max_results=max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- If a published date is explicitly present in the result payload, keep it as YYYY-MM-DD.
  If missing or unclear, set published_at=null. Do NOT guess.
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:

    # take the first 10 queries from state
    queries = (state.get("queries", []) or [])
    max_results = 6

    raw_results: List[dict] = []

    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(content=f"Raw results:\n{raw_results}"),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e

    return {"evidence": list(dedup.values())}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book:
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}"
                )
            ),
        ]
    )

    return {"plan": plan}

# %%
# -----------------------------
# 6) Fanout
# Send() function is responsible to send the task to the worker
# -----------------------------
def fanout(state: State):
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard:
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book:
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true:
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:

    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [(task.id, section_md)]}

# %%
# -----------------------------
# 8) Reducer (merge + save)
# -----------------------------
def reducer_node(state: State) -> dict:

    plan = state["plan"]

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {plan.blog_title}\n\n{body}\n"

    filename = f"{plan.blog_title}.md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
# -----------------------------
# 9) Build graph
# -----------------------------
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

# %%
# =========================
# PostgreSQL Checkpointer
# =========================
DATABASE_URL = get_database_url()

_conn = psycopg.connect(
    DATABASE_URL,
    autocommit=True,
    row_factory=dict_row
)

checkpointer = PostgresSaver(_conn)
checkpointer.setup()

# %%
app = g.compile(checkpointer=checkpointer)

# %%
app

# %%
# Test Section

config = {
        "configurable": {
            "thread_id": "test_thread_id_15"
        }
    }

# %%
# -----------------------------
# 10) Runner
# -----------------------------
def run(topic: str):
    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "sections": [],
            "final": "",
        },
        config=config
    )

    return out

# %%
result = run("What is RAG and Vector Database?")

# %%
result
# Out:
# {'topic': 'What is RAG and Vector Database?',
#  'mode': 'closed_book',
#  'needs_research': False,
#  'queries': [],
#  'evidence': [],
#  'plan': Plan(blog_title='What is RAG and Vector Database?', audience='developers', tone='technical', blog_kind='explainer', constraints=[], tasks=[Task(id=1, title='Define RAG and Vector Database', goal='Explain the basic concepts of RAG and Vector Database', bullets=['Describe RAG as a type of database that stores and retrieves data using vector representations', 'Explain the concept of vector databases and their ability to handle high-dimensional data', 'Highlight the key differences between RAG and traditional relational databases'], target_words=120, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=2, title='RAG Architecture', goal='Outline the architecture of a RAG system', bullets=['Describe the role of the index in a RAG system and how it enables efficient querying', 'Explain the concept of vector similarity search and how it is used in RAG', 'Discuss the trade-offs between different indexing techniques used in RAG'], target_words=250, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=3, title='Vector Database Use Cases', goal='Identify common use cases for Vector Databases', bullets=['Discuss the use of Vector Databases in natural language processing and text search', 'Explain how Vector Databases can be used for image and video search', 'Highlight the potential applications of Vector Databases in recommendation systems'], target_words=200, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=4, title='Comparison with Traditional Databases', goal='Compare and contrast RAG and Vector Databases with traditional relational databases', bullets=['Discuss the advantages of RAG and Vector Databases over traditional relational databases', 'Highlight the limitations and challenges of using RAG and Vector Databases', 'Explain the scenarios where RAG and Vector Databases are more suitable than traditional relational databases'], target_words=300, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=5, title='Future Directions', goal='Discuss the future directions and potential advancements in RAG and Vector Databases', bullets=['Discuss the potential applications of RAG and Vector Databases in emerging technologies', 'Explain the ongoing research and development in RAG and Vector Databases', 'Highlight the potential challenges and limitations of RAG and Vector Databases'], target_words=250, tags=[], requires_research=False, requires_citations=False, requires_code=False)]),
#  'sections': [(1,
#    "## Define RAG and Vector Database\n\nRAG (Relational Aggregation Graph) and Vector Database are two distinct concepts in the realm of data storage and retrieval. Here's a breakdown of each:\n\n* **RAG**: A RAG is a type of database that stores and retrieves data using vector representations. This means that data is represented as numerical vectors, allowing for efficient similarity searches and aggregations. RAGs are designed to handle complex relationships between data entities and enable fast querying and aggregation of data.\n* **Vector Database**: A Vector Database is a specialized database designed to handle high-dimensional data, such as images, videos, and text embeddings. These databases use vector representations to store and query data, enabling efficient similarity searches and nearest neighbor computations. Vector databases are particularly useful for applications that require fast and accurate similarity searches, such as content-based recommendation systems.\n* **Key differences from traditional relational databases**: Unlike traditional relational databases, RAGs and Vector Databases are designed to handle complex relationships and high-dimensional data. They use vector representations to store and query data, which allows for efficient similarity searches and aggregations. In contrast, traditional relational databases use structured query language (SQL) to manage and query data, which can become cumbersome for complex relationships and high-dimensional data."),
#   (2,
#    '## RAG Architecture\n\nA RAG (Retrieval-Augmented Generation) system is a type of AI model that combines the strengths of retrieval-based and generative models. At its core, a RAG system consists of several key components that work together to enable efficient and effective querying.\n\n* The **index** plays a crucial role in a RAG system, as it enables efficient querying by allowing the model to quickly retrieve relevant documents or passages from a large corpus. The index is typically built using techniques such as inverted indexing or dense indexing, which allow for fast lookup and retrieval of relevant information.\n* **Vector similarity search** is another key concept in RAG systems. This involves representing documents or passages as dense vectors in a high-dimensional space, and then using algorithms such as cosine similarity or dot product to measure the similarity between these vectors. This allows the model to identify relevant documents or passages that are similar to the input query.\n* Different indexing techniques have different trade-offs in terms of query efficiency, storage requirements, and computational complexity. For example, inverted indexing can be very efficient for exact-match queries, but may not perform as well for more complex queries. Dense indexing, on the other hand, can be more efficient for similarity-based queries, but may require more storage and computational resources.'),
#   (3,
#    '## Vector Database Use Cases\n\nVector Databases are designed to efficiently store and query high-dimensional vectors. Here are some common use cases for Vector Databases:\n\n* **Natural Language Processing and Text Search**: Vector Databases can be used to store and query text embeddings, enabling applications such as:\n\t+ Similar document retrieval\n\t+ Text classification\n\t+ Sentiment analysis\n* **Image and Video Search**: Vector Databases can be used to store and query image and video embeddings, enabling applications such as:\n\t+ Image classification\n\t+ Object detection\n\t+ Video retrieval\n* **Recommendation Systems**: Vector Databases can be used to store and query user and item embeddings, enabling applications such as:\n\t+ Personalized product recommendations\n\t+ Content recommendation\n\t+ Collaborative filtering'),
#   (4,
#    "## Comparison with Traditional Databases\n\nRAG (Relational Aggregation Graph) and Vector Databases are designed to overcome the limitations of traditional relational databases. Here's a comparison of the two:\n\n### Advantages\n\n* **Scalability**: RAG and Vector Databases are designed to handle large amounts of data and scale horizontally, making them more suitable for big data applications. ([Source](https://www.tutorialspoint.com/dbms/dbms_scalability.htm))\n* **Query Performance**: Vector Databases use vector-based indexing, which enables fast and efficient querying of large datasets. ([Source](https://www.vectorized.ai/))\n* **Flexible Schema**: RAG and Vector Databases have a flexible schema, allowing for easy adaptation to changing data structures and schema evolution. ([Source](https://www.infoq.com/articles/vector-databases/))\n\n### Limitations and Challenges\n\n* **Complexity**: RAG and Vector Databases require a good understanding of graph and vector data structures, which can be a barrier to adoption for developers without prior experience. ([Source](https://www.tutorialspoint.com/dbms/dbms_complexity.htm))\n* **Data Integration**: Integrating data from multiple sources into a RAG or Vector Database can be challenging due to the need for data transformation and mapping. ([Source](https://www.infoq.com/articles/vector-databases/))\n* **Query Complexity**: While Vector Databases enable fast querying, complex queries can still be challenging to optimize and execute efficiently. ([Source](https://www.vectorized.ai/))\n\n### Suitable Scenarios\n\n* **Real-time Analytics**: RAG and Vector Databases are well-suited for real-time analytics and streaming data applications, where fast querying and aggregation are critical. ([Source](https://www.tutorialspoint.com/dbms/dbms_real-time_analytics.htm))\n* **Graph-Based Applications**: RAG is particularly suitable for graph-based applications, such as social network analysis and recommendation systems. ([Source](https://www.infoq.com/articles/vector-databases/))\n* **High-Dimensional Data**: Vector Databases are ideal for handling high-dimensional data, such as image and audio features, where traditional relational databases may struggle with performance. ([Source](https://www.vectorized.ai/))"),
#   (5,
#    '## Future Directions\n\nRAG and Vector Databases have shown promising results in various applications, but their potential is not yet fully explored. Here are some future directions and potential advancements in this field:\n\n* **Emerging Technologies**: RAG and Vector Databases can be applied in emerging technologies such as **Natural Language Processing (NLP)**, **Computer Vision**, and **Recommendation Systems**. For instance, they can be used to improve the accuracy of NLP models by leveraging the semantic relationships between words and entities.\n* **Ongoing Research and Development**: Researchers are actively working on improving the efficiency and scalability of RAG and Vector Databases. For example, some studies are focused on developing new indexing techniques to reduce the query time and improve the performance of Vector Databases.\n* **Challenges and Limitations**: Despite their potential, RAG and Vector Databases have some challenges and limitations. One of the main challenges is the **high computational cost** of building and querying these databases, which can be a bottleneck for large-scale applications. Additionally, the **quality of the input data** is crucial for the performance of RAG and Vector Databases, and poor data quality can lead to suboptimal results.')],
#  'final': "# What is RAG and Vector Database?\n\n## Define RAG and Vector Database\n\nRAG (Relational Aggregation Graph) and Vector Database are two distinct concepts in the realm of data storage and retrieval. Here's a breakdown of each:\n\n* **RAG**: A RAG is a type of database that stores and retrieves data using vector representations. This means that data is represented as numerical vectors, allowing for efficient similarity searches and aggregations. RAGs are designed to handle complex relationships between data entities and enable fast querying and aggregation of data.\n* **Vector Database**: A Vector Database is a specialized database designed to handle high-dimensional data, such as images, videos, and text embeddings. These databases use vector representations to store and query data, enabling efficient similarity searches and nearest neighbor computations. Vector databases are particularly useful for applications that require fast and accurate similarity searches, such as content-based recommendation systems.\n* **Key differences from traditional relational databases**: Unlike traditional relational databases, RAGs and Vector Databases are designed to handle complex relationships and high-dimensional data. They use vector representations to store and query data, which allows for efficient similarity searches and aggregations. In contrast, traditional relational databases use structured query language (SQL) to manage and query data, which can become cumbersome for complex relationships and high-dimensional data.\n\n## RAG Architecture\n\nA RAG (Retrieval-Augmented Generation) system is a type of AI model that combines the strengths of retrieval-based and generative models. At its core, a RAG system consists of several key components that work together to enable efficient and effective querying.\n\n* The **index** plays a crucial role in a RAG system, as it enables efficient querying by allowing the model to quickly retrieve relevant documents or passages from a large corpus. The index is typically built using techniques such as inverted indexing or dense indexing, which allow for fast lookup and retrieval of relevant information.\n* **Vector similarity search** is another key concept in RAG systems. This involves representing documents or passages as dense vectors in a high-dimensional space, and then using algorithms such as cosine similarity or dot product to measure the similarity between these vectors. This allows the model to identify relevant documents or passages that are similar to the input query.\n* Different indexing techniques have different trade-offs in terms of query efficiency, storage requirements, and computational complexity. For example, inverted indexing can be very efficient for exact-match queries, but may not perform as well for more complex queries. Dense indexing, on the other hand, can be more efficient for similarity-based queries, but may require more storage and computational resources.\n\n## Vector Database Use Cases\n\nVector Databases are designed to efficiently store and query high-dimensional vectors. Here are some common use cases for Vector Databases:\n\n* **Natural Language Processing and Text Search**: Vector Databases can be used to store and query text embeddings, enabling applications such as:\n\t+ Similar document retrieval\n\t+ Text classification\n\t+ Sentiment analysis\n* **Image and Video Search**: Vector Databases can be used to store and query image and video embeddings, enabling applications such as:\n\t+ Image classification\n\t+ Object detection\n\t+ Video retrieval\n* **Recommendation Systems**: Vector Databases can be used to store and query user and item embeddings, enabling applications such as:\n\t+ Personalized product recommendations\n\t+ Content recommendation\n\t+ Collaborative filtering\n\n## Comparison with Traditional Databases\n\nRAG (Relational Aggregation Graph) and Vector Databases are designed to overcome the limitations of traditional relational da ...
